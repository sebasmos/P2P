# %% [markdown]
# Based on https://github.com/sebasmos/vcg/blob/main/Training_Plot_With_Loss/Plotting_Loss.ipynb

# %%
import pickle
with open('loss.pkl', 'rb') as f:
    Loss_per_epoch = pickle.load(f)

# %%
len(Loss_per_epoch)
# Out:
# 132

# %%
len(Loss_per_epoch[0])
# Out:
# 20

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.DataFrame(Loss_per_epoch)
columns = {0:'Hoechst',
           1:'AF1',
           2:'CD31',
           3:'CD45',
           4:'CD68',
           5:'Blank',
           6:'CD4',
           7:'FOXP3',
           8:'CD8a',
           9:'CD45RO',
           10:'CD20',
           11:'PD-L1',    
           12:'CD3e',
           13:'CD163',
           14:'E-Cadherin',
           15:'PD-1',
           16:'Ki-67',
           17:'Pan-CK',
           18:'SMA'
            }
df.rename(columns=columns, inplace=True)
df
# Out:
#        Hoechst        AF1       CD31      CD45      CD68      Blank       CD4  \
# 0    18.202793  18.170317  15.550015  8.973895  7.489675  10.343237  9.728122
# 1    18.053969  18.190102  15.758989  8.811481  7.265263  10.247257  9.724289
# 2    17.977070  18.246030  15.863411  8.739477  7.203688  10.363509  9.691946
# 3    18.010437  18.436364  15.922998  8.717437  7.217101  10.498561  9.717148
# 4    18.015066  18.445275  15.827342  8.701695  7.168768  10.572137  9.706580
# ..         ...        ...        ...       ...       ...        ...       ...
# 127  17.014689  14.627851  12.967586  8.077771  6.499734  11.541588  9.372589
# 128  17.013364  14.619898  12.960913  8.077039  6.499115  11.543819  9.370973
# 129  17.010780  14.611316  12.952879  8.076389  6.497724  11.547881  9.370155
# 130  17.008435  14.604072  12.944968  8.076204  6.496834  11.550000  9.369713
# 131  17.006985  14.596192  12.936799  8.075871  6.495445  11.553313  9.368348
#
#          FOXP3       CD8a     CD45RO       CD20      PD-L1       CD3e  \
# 0    17.709222  11.023404  15.567228  13.638824  14.712235  12.031815
# 1    18.445733  11.164433  15.461541  13.671328  14.663513  12.063480
# 2    18.602681  11.180648  15.356840  13.726688  14.675318  12.022468
# 3    18.746812  11.289760  15.252672  13.788388  14.703066  12.050151
# 4    18.769117  11.280432  15.169643  13.860759  14.731116  12.046879
# ..         ...        ...        ...        ...        ...        ...
# 127  15.895749   9.604117  13.620271  14.260045  14.941298  11.219835
# 128  15.881597   9.596300  13.615800  14.259443  14.939938  11.214645
# 129  15.869392   9.587669  13.610875  14.256935  14.938573  11.208869
# 130  15.856636   9.580040  13.607372  14.256120  14.937161  11.203576
# 131  15.843435   9.571299  13.602955  14.254110  14.935381  11.198062
#
#          CD163  E-Cadherin       PD-1      Ki-67     Pan-CK        SMA   19
# 0    14.092452   16.532119  13.082426  12.505486  18.317902  16.892571    1
# 1    14.098337   16.893003  13.167537  12.523424  18.690413  16.875301    2
# 2    13.944525   17.032209  13.143627  12.506923  18.889743  16.741695    3
# 3    13.891237   17.083303  13.174331  12.571126  19.010378  16.638313    4
# 4    13.862331   17.229297  13.115131  12.592890  19.225077  16.496131    5
# ..         ...         ...        ...        ...        ...        ...  ...
# 127  12.568226   15.588983  12.300080  11.389741  16.759647  14.355353  128
# 128  12.560326   15.582461  12.296197  11.384861  16.750175  14.346434  129
# 129  12.552357   15.575876  12.290705  11.380150  16.740460  14.337129  130
# 130  12.544765   15.570826  12.286411  11.376344  16.731544  14.328949  131
# 131  12.538456   15.563818  12.281446  11.371675  16.721630  14.319967  132
#
# [132 rows x 20 columns]

# %%
n_ch= len(df.columns)

# %%
df.iloc[:,:n_ch-1]
# Out:
#        Hoechst        AF1       CD31      CD45      CD68      Blank       CD4  \
# 0    18.202793  18.170317  15.550015  8.973895  7.489675  10.343237  9.728122
# 1    18.053969  18.190102  15.758989  8.811481  7.265263  10.247257  9.724289
# 2    17.977070  18.246030  15.863411  8.739477  7.203688  10.363509  9.691946
# 3    18.010437  18.436364  15.922998  8.717437  7.217101  10.498561  9.717148
# 4    18.015066  18.445275  15.827342  8.701695  7.168768  10.572137  9.706580
# ..         ...        ...        ...       ...       ...        ...       ...
# 127  17.014689  14.627851  12.967586  8.077771  6.499734  11.541588  9.372589
# 128  17.013364  14.619898  12.960913  8.077039  6.499115  11.543819  9.370973
# 129  17.010780  14.611316  12.952879  8.076389  6.497724  11.547881  9.370155
# 130  17.008435  14.604072  12.944968  8.076204  6.496834  11.550000  9.369713
# 131  17.006985  14.596192  12.936799  8.075871  6.495445  11.553313  9.368348
#
#          FOXP3       CD8a     CD45RO       CD20      PD-L1       CD3e  \
# 0    17.709222  11.023404  15.567228  13.638824  14.712235  12.031815
# 1    18.445733  11.164433  15.461541  13.671328  14.663513  12.063480
# 2    18.602681  11.180648  15.356840  13.726688  14.675318  12.022468
# 3    18.746812  11.289760  15.252672  13.788388  14.703066  12.050151
# 4    18.769117  11.280432  15.169643  13.860759  14.731116  12.046879
# ..         ...        ...        ...        ...        ...        ...
# 127  15.895749   9.604117  13.620271  14.260045  14.941298  11.219835
# 128  15.881597   9.596300  13.615800  14.259443  14.939938  11.214645
# 129  15.869392   9.587669  13.610875  14.256935  14.938573  11.208869
# 130  15.856636   9.580040  13.607372  14.256120  14.937161  11.203576
# 131  15.843435   9.571299  13.602955  14.254110  14.935381  11.198062
#
#          CD163  E-Cadherin       PD-1      Ki-67     Pan-CK        SMA
# 0    14.092452   16.532119  13.082426  12.505486  18.317902  16.892571
# 1    14.098337   16.893003  13.167537  12.523424  18.690413  16.875301
# 2    13.944525   17.032209  13.143627  12.506923  18.889743  16.741695
# 3    13.891237   17.083303  13.174331  12.571126  19.010378  16.638313
# 4    13.862331   17.229297  13.115131  12.592890  19.225077  16.496131
# ..         ...         ...        ...        ...        ...        ...
# 127  12.568226   15.588983  12.300080  11.389741  16.759647  14.355353
# 128  12.560326   15.582461  12.296197  11.384861  16.750175  14.346434
# 129  12.552357   15.575876  12.290705  11.380150  16.740460  14.337129
# 130  12.544765   15.570826  12.286411  11.376344  16.731544  14.328949
# 131  12.538456   15.563818  12.281446  11.371675  16.721630  14.319967
#
# [132 rows x 19 columns]

# %%
import seaborn as sns
palette = sns.color_palette("husl", (n_ch-1)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 10))
# Adding grid
sns.set(style="ticks")
#sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,:n_ch-1], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 5)

plt.legend(loc='lower right')
plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.grid()

#plt.legend(labels=['legendEntry1', 'legendEntry2', 'legendEntry3', 'legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3','legendEntry2', 'legendEntry3'])

plt.show()
plt.close('all')

# %%
import seaborn as sns
palette = sns.color_palette("husl", n_ch-1) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 10))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,:n_ch-1], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 5)

plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %%
import seaborn as sns
channels = [17,7, 14]
palette = sns.color_palette("husl", len(channels)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (5, 5))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,channels], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 2)

plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %%
import seaborn as sns
channels = [0,1,2,3,4,5,6,8,9,10,11,12,13,15,16,18]
palette = sns.color_palette("husl", len(channels)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 10))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,channels], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 2)

plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %%
import seaborn as sns
channels = [0,1,3,5,17]
palette = sns.color_palette("husl", len(channels)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 5))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,channels], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 2)
#plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.title("L1 per channel")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %% [markdown]
# ### Legend locations
# ```
# upper right
# upper left
# lower left
# lower right
# right
# center left
# center right
# lower center
# upper center
# center
# ```
